# %%
f=lambda x:x*2+x+10
print(f(2))
# Out:
# 16

# %%
print(f(10))
# Out:
# 40

# %%
print(f(30)+200)
# Out:
# 300

# %%
g=lambda x,y:x*y+10-y**2
g(12,5)
# Out:
# 45

# %%
area_of_circle=lambda r:22/7*r**2

# %%
area_of_circle(3)
# Out:
# 28.285714285714285

# %% [markdown]
# # Map and filter

# %%
x=[1,2,3,5]         #data
x2=[i**2 for i in x]       #comprehession

# %%
### data processing functions 
#-map() -same opreation

# %%
map(int )

# %%
for num  in map(int,['1','3','5','10']):
    print()

# %%
for ascii_code in map(ord,['a','b','c','d']):
    print(ascii_code,end=' ')
# Out:
# 97 98 99 100

# %%
list(map(ord,['a','b','c','d']))
# Out:
# [97, 98, 99, 100]

# %%
tuple(map(round,[12,36,1.3533,2.333]))
# Out:
# (12, 36, 1, 2)

# %%
list(map(round,[12,34,1.33,23.33]))
# Out:
# [12, 34, 1, 23]

# %%
set(map(round,[12,34,1.3333,23.1245]))
# Out:
# {1, 12, 23, 34}

# %%
animals=['lion','tiger','cow','horse','dear','wolf','cat','dog']

lambda e:e[0]
map(lambda e:e[0],animals)

# %%
out=list(map(lambda e:e[0],animals))
print(out)
# Out:
# ['l', 't', 'c', 'h', 'd', 'w', 'c', 'd']

# %%
out=list(map(lambda e:e[2],animals))
print(out)
# Out:
# ['o', 'g', 'w', 'r', 'a', 'l', 't', 'g']

# %%
list(map(lambda e: e[:3],animals))
# Out:
# ['lio', 'tig', 'cow', 'hor', 'dea', 'wol', 'cat', 'dog']

# %%
list(map(lambda e:e[:2],animals))
# Out:
# ['li', 'ti', 'co', 'ho', 'de', 'wo', 'ca', 'do']

# %%
fruits=['apple','banana','berry','cherry','pineapple','guava','dragon fruit','water melon']
print(fruits)
print(len(fruits))
print(len(fruits)==len(animals))
# Out:
# ['apple', 'banana', 'berry', 'cherry', 'pineapple', 'guava', 'dragon fruit', 'water melon']
# 8
# True

# %%
#first three letters of animal and last 3 of fruit 
list(map(lambda a,f: a[:3]+f[-3:],animals,fruits))
# Out:
# ['liople',
#  'tigana',
#  'cowrry',
#  'horrry',
#  'deaple',
#  'wolava',
#  'catuit',
#  'doglon']

# %%
x,y=[1,2,3],[3,4,5]
z=list(map(lambda i,j: i+j,x,y))
print(x,y,z,sep='\n')
# Out:
# [1, 2, 3]
# [3, 4, 5]
# [4, 6, 8]

# %%
path='c:/program'

# %%
class Student:
    def _init_(self, name, marks=[]):
        self.name = name
        self.marks = marks

    def total_marks(self):
        return sum(self.marks)
    
    def _gt_(self, other):
        if isinstance(other, Student):
            return self.total_marks() > other.total_marks()
        elif isinstance(other, int):
            return self.total_marks() > other
    
    def _repr_(self):
        return f'Student({self.name}, {self.total_marks()})'
    

# Function to check pass/fail
def is_passed(student):
    return student.total_marks() > 200


# List of students
students = [
    Student('Kelsier', [23, 50, 67, 20, 10]),
    Student('Vin', [43, 86, 77]),
    Student('Rashek', [83, 86, 87]),
    Student('Sazed', [53, 86, 67]),
]

# Filtering passed students
passed_students = list(filter(is_passed, students))

print(passed_students)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 26
#      21     return student.total_marks() > 200
#      24 # List of students
#      25 students = [
# ---> 26     Student('Kelsier', [23, 50, 67, 20, 10]),
#      27     Student('Vin', [43, 86, 77]),
#      28     Student('Rashek', [83, 86, 87]),
#      29     Student('Sazed', [53, 86, 67]),
#      30 ]
#      32 # Filtering passed students
#      33 passed_students = list(filter(is_passed, students))
#
# TypeError: Student() takes no arguments
